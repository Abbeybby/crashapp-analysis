# %%
import pandas as pd

# %%
df=pd.read_csv("aircrahesFullDataUpdated_2024.csv")

# %%
df
# Out:
#       Year Quarter      Month  Day Country/Region     Aircraft Manufacturer  \
# 0     1970   Qtr 2      April   28            NaN       de Havilland Canada
# 1     1952   Qtr 2      April   30            NaN                   Douglas
# 2     1973   Qtr 2      April   10            NaN          Vickers Vanguard
# 3     2000   Qtr 2      April   19             '-                   Antonov
# 4     1946   Qtr 2      April   30             '-                   Douglas
# ...    ...     ...        ...  ...            ...                       ...
# 5030  1980   Qtr 3  September   17          Zaire              De Havilland
# 5031  1997   Qtr 3  September   12          Zaire       de Havilland Canada
# 5032  1984   Qtr 3  September   11          Zaire  Handley Page Dart Herald
# 5033  1980   Qtr 3  September   14          Zaire         Lockheed Hercules
# 5034  1961   Qtr 3  September   17         Zambia                   Douglas
#
#                                         Aircraft                     Location  \
# 0     de Havilland Canada DHC 6 Twin Otter 100VH                      Kainatu
# 1                                 Douglas DC 3VT                        Delhi
# 2                     Vickers Vanguard 952G AXOP                   Near Basel
# 3                                 Antonov AN 8TL                      Pepa  -
# 4                            Douglas C 47A FZ559                Pindi-Khut  -
# ...                                          ...                          ...
# 5030                de Havilland DHC 5 Buffalo9T             Near Kindu Zaire
# 5031  de Havilland Canada DHC 6 Twin Otter 3009Q             Near Uvira Zaire
# 5032          Handley Page Dart Herald 2029Q CAH  Near the Kwango River Zaire
# 5033                   Lockheed Hercules C 1309T                  Kindu Zaire
# 5034                             Douglas DC 6BSE                 Ndola Zambia
#
#                                             Operator  Ground  \
# 0                 Airlines Australia GuineaTrans New       0
# 1                                Airways IndiaDeccan       0
# 2     (UK) Airlines International SwitzerlandInvicta       0
# 3                             Airlines Centrafricain       0
# 4                                    Force Air Royal       0
# ...                                              ...     ...
# 5030                    Force Air Zairean - Military       0
# 5031                                Commuter Air TMK       0
# 5032                               Services Aero MMM       0
# 5033              Zaïroise Aérienne Force - Military       0
# 5034                                 Sweden Transair       0
#
#       Fatalities (air)  Aboard
# 0                    8      11
# 1                    9       9
# 2                  108     145
# 3                   24      24
# 4                   12      12
# ...                ...     ...
# 5030                36      36
# 5031                22      22
# 5032                30      30
# 5033                36      36
# 5034                16      16
#
# [5035 rows x 12 columns]

# %%
df["Country/Region"] = df["Country/Region"].str.replace("'-","unknown").str.strip()

# %%
df["Country/Region"]
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3       unknown
# 4       unknown
#          ...
# 5030      Zaire
# 5031      Zaire
# 5032      Zaire
# 5033      Zaire
# 5034     Zambia
# Name: Country/Region, Length: 5035, dtype: object

# %%
df
# Out:
#       Year Quarter      Month  Day Country/Region     Aircraft Manufacturer  \
# 0     1970   Qtr 2      April   28            NaN       de Havilland Canada
# 1     1952   Qtr 2      April   30            NaN                   Douglas
# 2     1973   Qtr 2      April   10            NaN          Vickers Vanguard
# 3     2000   Qtr 2      April   19        unknown                   Antonov
# 4     1946   Qtr 2      April   30        unknown                   Douglas
# ...    ...     ...        ...  ...            ...                       ...
# 5030  1980   Qtr 3  September   17          Zaire              De Havilland
# 5031  1997   Qtr 3  September   12          Zaire       de Havilland Canada
# 5032  1984   Qtr 3  September   11          Zaire  Handley Page Dart Herald
# 5033  1980   Qtr 3  September   14          Zaire         Lockheed Hercules
# 5034  1961   Qtr 3  September   17         Zambia                   Douglas
#
#                                         Aircraft                     Location  \
# 0     de Havilland Canada DHC 6 Twin Otter 100VH                      Kainatu
# 1                                 Douglas DC 3VT                        Delhi
# 2                     Vickers Vanguard 952G AXOP                   Near Basel
# 3                                 Antonov AN 8TL                      Pepa  -
# 4                            Douglas C 47A FZ559                Pindi-Khut  -
# ...                                          ...                          ...
# 5030                de Havilland DHC 5 Buffalo9T             Near Kindu Zaire
# 5031  de Havilland Canada DHC 6 Twin Otter 3009Q             Near Uvira Zaire
# 5032          Handley Page Dart Herald 2029Q CAH  Near the Kwango River Zaire
# 5033                   Lockheed Hercules C 1309T                  Kindu Zaire
# 5034                             Douglas DC 6BSE                 Ndola Zambia
#
#                                             Operator  Ground  \
# 0                 Airlines Australia GuineaTrans New       0
# 1                                Airways IndiaDeccan       0
# 2     (UK) Airlines International SwitzerlandInvicta       0
# 3                             Airlines Centrafricain       0
# 4                                    Force Air Royal       0
# ...                                              ...     ...
# 5030                    Force Air Zairean - Military       0
# 5031                                Commuter Air TMK       0
# 5032                               Services Aero MMM       0
# 5033              Zaïroise Aérienne Force - Military       0
# 5034                                 Sweden Transair       0
#
#       Fatalities (air)  Aboard
# 0                    8      11
# 1                    9       9
# 2                  108     145
# 3                   24      24
# 4                   12      12
# ...                ...     ...
# 5030                36      36
# 5031                22      22
# 5032                30      30
# 5033                36      36
# 5034                16      16
#
# [5035 rows x 12 columns]

# %%
df.fillna("Not Available")
# Out:
#       Year Quarter      Month  Day Country/Region     Aircraft Manufacturer  \
# 0     1970   Qtr 2      April   28  Not Available       de Havilland Canada
# 1     1952   Qtr 2      April   30  Not Available                   Douglas
# 2     1973   Qtr 2      April   10  Not Available          Vickers Vanguard
# 3     2000   Qtr 2      April   19        unknown                   Antonov
# 4     1946   Qtr 2      April   30        unknown                   Douglas
# ...    ...     ...        ...  ...            ...                       ...
# 5030  1980   Qtr 3  September   17          Zaire              De Havilland
# 5031  1997   Qtr 3  September   12          Zaire       de Havilland Canada
# 5032  1984   Qtr 3  September   11          Zaire  Handley Page Dart Herald
# 5033  1980   Qtr 3  September   14          Zaire         Lockheed Hercules
# 5034  1961   Qtr 3  September   17         Zambia                   Douglas
#
#                                         Aircraft                     Location  \
# 0     de Havilland Canada DHC 6 Twin Otter 100VH                      Kainatu
# 1                                 Douglas DC 3VT                        Delhi
# 2                     Vickers Vanguard 952G AXOP                   Near Basel
# 3                                 Antonov AN 8TL                      Pepa  -
# 4                            Douglas C 47A FZ559                Pindi-Khut  -
# ...                                          ...                          ...
# 5030                de Havilland DHC 5 Buffalo9T             Near Kindu Zaire
# 5031  de Havilland Canada DHC 6 Twin Otter 3009Q             Near Uvira Zaire
# 5032          Handley Page Dart Herald 2029Q CAH  Near the Kwango River Zaire
# 5033                   Lockheed Hercules C 1309T                  Kindu Zaire
# 5034                             Douglas DC 6BSE                 Ndola Zambia
#
#                                             Operator  Ground  \
# 0                 Airlines Australia GuineaTrans New       0
# 1                                Airways IndiaDeccan       0
# 2     (UK) Airlines International SwitzerlandInvicta       0
# 3                             Airlines Centrafricain       0
# 4                                    Force Air Royal       0
# ...                                              ...     ...
# 5030                    Force Air Zairean - Military       0
# 5031                                Commuter Air TMK       0
# 5032                               Services Aero MMM       0
# 5033              Zaïroise Aérienne Force - Military       0
# 5034                                 Sweden Transair       0
#
#       Fatalities (air)  Aboard
# 0                    8      11
# 1                    9       9
# 2                  108     145
# 3                   24      24
# 4                   12      12
# ...                ...     ...
# 5030                36      36
# 5031                22      22
# 5032                30      30
# 5033                36      36
# 5034                16      16
#
# [5035 rows x 12 columns]

# %%
df["Country/Region"]= df["Country/Region"].replace("10"," ", regex=True)

# %%
df["Country/Region"]
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3       unknown
# 4       unknown
#          ...
# 5030      Zaire
# 5031      Zaire
# 5032      Zaire
# 5033      Zaire
# 5034     Zambia
# Name: Country/Region, Length: 5035, dtype: object

# %%
df.isna().sum()
# Out:
# Year                       0
# Quarter                    0
# Month                      0
# Day                        0
# Country/Region           230
# Aircraft Manufacturer      0
# Aircraft                   0
# Location                   0
# Operator                 234
# Ground                     0
# Fatalities (air)           0
# Aboard                     0
# dtype: int64

# %%
df
# Out:
#       Year Quarter      Month  Day Country/Region     Aircraft Manufacturer  \
# 0     1970   Qtr 2      April   28            NaN       de Havilland Canada
# 1     1952   Qtr 2      April   30            NaN                   Douglas
# 2     1973   Qtr 2      April   10            NaN          Vickers Vanguard
# 3     2000   Qtr 2      April   19        unknown                   Antonov
# 4     1946   Qtr 2      April   30        unknown                   Douglas
# ...    ...     ...        ...  ...            ...                       ...
# 5030  1980   Qtr 3  September   17          Zaire              De Havilland
# 5031  1997   Qtr 3  September   12          Zaire       de Havilland Canada
# 5032  1984   Qtr 3  September   11          Zaire  Handley Page Dart Herald
# 5033  1980   Qtr 3  September   14          Zaire         Lockheed Hercules
# 5034  1961   Qtr 3  September   17         Zambia                   Douglas
#
#                                         Aircraft                     Location  \
# 0     de Havilland Canada DHC 6 Twin Otter 100VH                      Kainatu
# 1                                 Douglas DC 3VT                        Delhi
# 2                     Vickers Vanguard 952G AXOP                   Near Basel
# 3                                 Antonov AN 8TL                      Pepa  -
# 4                            Douglas C 47A FZ559                Pindi-Khut  -
# ...                                          ...                          ...
# 5030                de Havilland DHC 5 Buffalo9T             Near Kindu Zaire
# 5031  de Havilland Canada DHC 6 Twin Otter 3009Q             Near Uvira Zaire
# 5032          Handley Page Dart Herald 2029Q CAH  Near the Kwango River Zaire
# 5033                   Lockheed Hercules C 1309T                  Kindu Zaire
# 5034                             Douglas DC 6BSE                 Ndola Zambia
#
#                                             Operator  Ground  \
# 0                 Airlines Australia GuineaTrans New       0
# 1                                Airways IndiaDeccan       0
# 2     (UK) Airlines International SwitzerlandInvicta       0
# 3                             Airlines Centrafricain       0
# 4                                    Force Air Royal       0
# ...                                              ...     ...
# 5030                    Force Air Zairean - Military       0
# 5031                                Commuter Air TMK       0
# 5032                               Services Aero MMM       0
# 5033              Zaïroise Aérienne Force - Military       0
# 5034                                 Sweden Transair       0
#
#       Fatalities (air)  Aboard
# 0                    8      11
# 1                    9       9
# 2                  108     145
# 3                   24      24
# 4                   12      12
# ...                ...     ...
# 5030                36      36
# 5031                22      22
# 5032                30      30
# 5033                36      36
# 5034                16      16
#
# [5035 rows x 12 columns]

# %% [markdown]
# #df.fillna('unknown')

# %%
df['Aircraft Manufacturer'].str.strip()  # trim
# Out:
# 0            de Havilland Canada
# 1                        Douglas
# 2               Vickers Vanguard
# 3                        Antonov
# 4                        Douglas
#                   ...
# 5030                De Havilland
# 5031         de Havilland Canada
# 5032    Handley Page Dart Herald
# 5033           Lockheed Hercules
# 5034                     Douglas
# Name: Aircraft Manufacturer, Length: 5035, dtype: object

# %%
df
# Out:
#       Year Quarter      Month  Day Country/Region     Aircraft Manufacturer  \
# 0     1970   Qtr 2      April   28            NaN       de Havilland Canada
# 1     1952   Qtr 2      April   30            NaN                   Douglas
# 2     1973   Qtr 2      April   10            NaN          Vickers Vanguard
# 3     2000   Qtr 2      April   19        unknown                   Antonov
# 4     1946   Qtr 2      April   30        unknown                   Douglas
# ...    ...     ...        ...  ...            ...                       ...
# 5030  1980   Qtr 3  September   17          Zaire              De Havilland
# 5031  1997   Qtr 3  September   12          Zaire       de Havilland Canada
# 5032  1984   Qtr 3  September   11          Zaire  Handley Page Dart Herald
# 5033  1980   Qtr 3  September   14          Zaire         Lockheed Hercules
# 5034  1961   Qtr 3  September   17         Zambia                   Douglas
#
#                                         Aircraft                     Location  \
# 0     de Havilland Canada DHC 6 Twin Otter 100VH                      Kainatu
# 1                                 Douglas DC 3VT                        Delhi
# 2                     Vickers Vanguard 952G AXOP                   Near Basel
# 3                                 Antonov AN 8TL                      Pepa  -
# 4                            Douglas C 47A FZ559                Pindi-Khut  -
# ...                                          ...                          ...
# 5030                de Havilland DHC 5 Buffalo9T             Near Kindu Zaire
# 5031  de Havilland Canada DHC 6 Twin Otter 3009Q             Near Uvira Zaire
# 5032          Handley Page Dart Herald 2029Q CAH  Near the Kwango River Zaire
# 5033                   Lockheed Hercules C 1309T                  Kindu Zaire
# 5034                             Douglas DC 6BSE                 Ndola Zambia
#
#                                             Operator  Ground  \
# 0                 Airlines Australia GuineaTrans New       0
# 1                                Airways IndiaDeccan       0
# 2     (UK) Airlines International SwitzerlandInvicta       0
# 3                             Airlines Centrafricain       0
# 4                                    Force Air Royal       0
# ...                                              ...     ...
# 5030                    Force Air Zairean - Military       0
# 5031                                Commuter Air TMK       0
# 5032                               Services Aero MMM       0
# 5033              Zaïroise Aérienne Force - Military       0
# 5034                                 Sweden Transair       0
#
#       Fatalities (air)  Aboard
# 0                    8      11
# 1                    9       9
# 2                  108     145
# 3                   24      24
# 4                   12      12
# ...                ...     ...
# 5030                36      36
# 5031                22      22
# 5032                30      30
# 5033                36      36
# 5034                16      16
#
# [5035 rows x 12 columns]

# %%
df['Country/Region'].str.strip()
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3       unknown
# 4       unknown
#          ...
# 5030      Zaire
# 5031      Zaire
# 5032      Zaire
# 5033      Zaire
# 5034     Zambia
# Name: Country/Region, Length: 5035, dtype: object

# %%
df['Aircraft'].str.strip()
# Out:
# 0       de Havilland Canada DHC 6 Twin Otter 100VH
# 1                                   Douglas DC 3VT
# 2                       Vickers Vanguard 952G AXOP
# 3                                   Antonov AN 8TL
# 4                              Douglas C 47A FZ559
#                            ...
# 5030                  de Havilland DHC 5 Buffalo9T
# 5031    de Havilland Canada DHC 6 Twin Otter 3009Q
# 5032            Handley Page Dart Herald 2029Q CAH
# 5033                     Lockheed Hercules C 1309T
# 5034                               Douglas DC 6BSE
# Name: Aircraft, Length: 5035, dtype: object

# %%
df['Location'].str.strip()
# Out:
# 0                           Kainatu
# 1                             Delhi
# 2                        Near Basel
# 3                           Pepa  -
# 4                     Pindi-Khut  -
#                    ...
# 5030               Near Kindu Zaire
# 5031               Near Uvira Zaire
# 5032    Near the Kwango River Zaire
# 5033                    Kindu Zaire
# 5034                   Ndola Zambia
# Name: Location, Length: 5035, dtype: object

# %%
df['Location'].str.replace("-","").str.strip()
# Out:
# 0                           Kainatu
# 1                             Delhi
# 2                        Near Basel
# 3                              Pepa
# 4                         PindiKhut
#                    ...
# 5030               Near Kindu Zaire
# 5031               Near Uvira Zaire
# 5032    Near the Kwango River Zaire
# 5033                    Kindu Zaire
# 5034                   Ndola Zambia
# Name: Location, Length: 5035, dtype: object

# %%
df['Operator'].str.strip()
# Out:
# 0                   Airlines Australia GuineaTrans New
# 1                                  Airways IndiaDeccan
# 2       (UK) Airlines International SwitzerlandInvicta
# 3                               Airlines Centrafricain
# 4                                      Force Air Royal
#                              ...
# 5030                      Force Air Zairean - Military
# 5031                                  Commuter Air TMK
# 5032                                 Services Aero MMM
# 5033                Zaïroise Aérienne Force - Military
# 5034                                   Sweden Transair
# Name: Operator, Length: 5035, dtype: object

# %%
# CHANGING DTYPE TO CATEGORY
df[['Month','Day']].astype('category')
# Out:
#           Month Day
# 0         April  28
# 1         April  30
# 2         April  10
# 3         April  19
# 4         April  30
# ...         ...  ..
# 5030  September  17
# 5031  September  12
# 5032  September  11
# 5033  September  14
# 5034  September  17
#
# [5035 rows x 2 columns]

# %%
# Reasearch question on Air crashes

# %% [markdown]
# 1) How has the rate of air crashes changed over time? increased or decreased or stable or unstable
# 2) What is the distribution of aircraft types involved in crashes
# 3) how does the number of crashes vary by year or month
# 4) What are the top aircraft manufacturers in the dataset
# 6) Countries that have the most plane crashes
# 7) which crashes resulted in the most fatalities and injuries
# 8) Has the rate of plane crashes decreased over time as safety regulations and technology have improved?
# 9) What are the trend in the number of people travelling abroad annually over the decade?
# 10) What is the trend in the number of deaths per year over time
# 11) whats is the individuals survived each year in the air crahes

# %%
import matplotlib
from matplotlib import pyplot as plt

# %%
sum_of_ground = df.groupby('Year')['Ground'].sum()

# %%
sum_of_ground
# Out:
# Year
# 1908    0
# 1909    0
# 1912    0
# 1913    0
# 1915    0
#        ..
# 2020    1
# 2021    3
# 2022    2
# 2023    0
# 2024    0
# Name: Ground, Length: 114, dtype: int64

# %%
fatalities_by_year = df.groupby('Year')['Fatalities (air)'].sum() #6

# %%
year_with_max_fatalities = fatalities_by_year.idxmax()

# %%
max_fatalities = fatalities_by_year.max()

# %%
print(f"year: {year_with_max_fatalities},fatalities:{max_fatalities}")
# Out:
# year: 1972,fatalities:2796

# %%
Sum_of_Aboard = df.groupby('Year')['Aboard'].sum()

# %%
Sum_of_Aboard
# Out:
# Year
# 1908      2
# 1909      1
# 1912      5
# 1913     49
# 1915     60
#        ...
# 2020    703
# 2021    247
# 2022    321
# 2023     86
# 2024    627
# Name: Aboard, Length: 114, dtype: int64

# %%
crash_counts = df['Year'].value_counts() # it counts from the highest to the lowest 1

# %%
crash_counts
# Out:
# Year
# 1946    88
# 1989    83
# 1947    82
# 1962    79
# 1948    78
#         ..
# 2023     2
# 1915     2
# 1912     1
# 1909     1
# 1908     1
# Name: count, Length: 114, dtype: int64

# %%
import matplotlib.pyplot as plt # 1

# %%
import seaborn as sns

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12,6))
sns.lineplot(x=crash_counts.index,y=crash_counts.values, palette='viridis')

plt.title('Number of Air crashes per year',fontsize=16)
plt.xlabel('Year',fontsize=14)
plt.ylabel('Number of crashes',fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3080\3678040047.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x=crash_counts.index,y=crash_counts.values, palette='viridis')

# %%
aircraft_count = df['Aircraft'].value_counts() #2

# %%
aircraft_count
# Out:
# Aircraft
# Boeing B 737              73
# Boeing B 727              56
# Boeing B 707              51
# McDonnell Douglas DC 9    42
# Douglas C 47A             39
#                           ..
# Douglas C 47CP             1
# Douglas C 54TAM            1
# Douglas EC 54UCP           1
# Avro 685 York 1G AHEX      1
# Douglas DC 6BSE            1
# Name: count, Length: 3525, dtype: int64

# %%
top_aircraft = aircraft_count.head(10)

# %%
top_aircraft
# Out:
# Aircraft
# Boeing B 737              73
# Boeing B 727              56
# Boeing B 707              51
# McDonnell Douglas DC 9    42
# Douglas C 47A             39
# Britten  Norman BN        37
# McDonnell Douglas DC 8    36
# Boeing B 747              30
# Douglas DC 3PP            24
# Douglas DC 3 (C           23
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12,6))
sns.barplot(x=top_aircraft.index,y=top_aircraft.values, palette='viridis')

plt.title('Topten Number of Aircraft per year',fontsize=16)
plt.xlabel('Aircraft',fontsize=14)
plt.ylabel('Number of aircraft crashes',fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3080\4232063058.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_aircraft.index,y=top_aircraft.values, palette='viridis')

# %%
crashes_by_year = df['Year'].value_counts() #3

# %%
crashes_by_year
# Out:
# Year
# 1946    88
# 1989    83
# 1947    82
# 1962    79
# 1948    78
#         ..
# 2023     2
# 1915     2
# 1912     1
# 1909     1
# 1908     1
# Name: count, Length: 114, dtype: int64

# %%
crashes_by_month = df['Month'].value_counts()

# %%
crashes_by_month
# Out:
# Month
# December     497
# January      467
# September    453
# August       452
# November     443
# July         428
# October      428
# March        427
# June         367
# February     362
# May          361
# April        350
# Name: count, dtype: int64

# %%
crashes_by_month.plot(kind='bar',figsize=(12,6),title='Number of crashes by Month') 
plt.xlabel('Month')
plt.ylabel('Number of crashes')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12,6))
sns.lineplot(x=crashes_by_year.index,y=crashes_by_year.values, palette='viridis')

plt.title('Number of Air crashes per year',fontsize=16)
plt.xlabel('Year',fontsize=14)
plt.ylabel('Number of crashes',fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3080\4284045375.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x=crashes_by_year.index,y=crashes_by_year.values, palette='viridis')

# %%
df
# Out:
#       Year Quarter      Month  Day Country/Region     Aircraft Manufacturer  \
# 0     1970   Qtr 2      April   28            NaN       de Havilland Canada
# 1     1952   Qtr 2      April   30            NaN                   Douglas
# 2     1973   Qtr 2      April   10            NaN          Vickers Vanguard
# 3     2000   Qtr 2      April   19        unknown                   Antonov
# 4     1946   Qtr 2      April   30        unknown                   Douglas
# ...    ...     ...        ...  ...            ...                       ...
# 5030  1980   Qtr 3  September   17          Zaire              De Havilland
# 5031  1997   Qtr 3  September   12          Zaire       de Havilland Canada
# 5032  1984   Qtr 3  September   11          Zaire  Handley Page Dart Herald
# 5033  1980   Qtr 3  September   14          Zaire         Lockheed Hercules
# 5034  1961   Qtr 3  September   17         Zambia                   Douglas
#
#                                         Aircraft                     Location  \
# 0     de Havilland Canada DHC 6 Twin Otter 100VH                      Kainatu
# 1                                 Douglas DC 3VT                        Delhi
# 2                     Vickers Vanguard 952G AXOP                   Near Basel
# 3                                 Antonov AN 8TL                      Pepa  -
# 4                            Douglas C 47A FZ559                Pindi-Khut  -
# ...                                          ...                          ...
# 5030                de Havilland DHC 5 Buffalo9T             Near Kindu Zaire
# 5031  de Havilland Canada DHC 6 Twin Otter 3009Q             Near Uvira Zaire
# 5032          Handley Page Dart Herald 2029Q CAH  Near the Kwango River Zaire
# 5033                   Lockheed Hercules C 1309T                  Kindu Zaire
# 5034                             Douglas DC 6BSE                 Ndola Zambia
#
#                                             Operator  Ground  \
# 0                 Airlines Australia GuineaTrans New       0
# 1                                Airways IndiaDeccan       0
# 2     (UK) Airlines International SwitzerlandInvicta       0
# 3                             Airlines Centrafricain       0
# 4                                    Force Air Royal       0
# ...                                              ...     ...
# 5030                    Force Air Zairean - Military       0
# 5031                                Commuter Air TMK       0
# 5032                               Services Aero MMM       0
# 5033              Zaïroise Aérienne Force - Military       0
# 5034                                 Sweden Transair       0
#
#       Fatalities (air)  Aboard
# 0                    8      11
# 1                    9       9
# 2                  108     145
# 3                   24      24
# 4                   12      12
# ...                ...     ...
# 5030                36      36
# 5031                22      22
# 5032                30      30
# 5033                36      36
# 5034                16      16
#
# [5035 rows x 12 columns]

# %%
air_manufacturer_count= df['Aircraft Manufacturer'].value_counts() 
air_manufacturer_count
# Out:
# Aircraft Manufacturer
# Douglas                994
# Boeing                 388
# Antonov                284
# Lockheed               211
# de Havilland Canada    157
#                       ...
# Curtiss Carrier          1
# Lockheed  188A           1
# Desoutter                1
# PAC                      1
# Wright Flyer             1
# Name: count, Length: 633, dtype: int64

# %%
top_Aircraft_Manufacturer = air_manufacturer_count.head(10)
top_Aircraft_Manufacturer
# Out:
# Aircraft Manufacturer
# Douglas                994
# Boeing                 388
# Antonov                284
# Lockheed               211
# de Havilland Canada    157
# Ilyushin               138
# Fokker                 126
# McDonnell Douglas      126
# Curtiss                125
# De Havilland           108
# Name: count, dtype: int64

# %%
top_Aircraft_Manufacturer.plot(kind='bar',figsize=(12,6),title= 'top aircraft manufacturers')
plt.xlabel('aircraft_manufacturer')
plt.ylabel('production rate')
plt.show()

# %%
country_count = df['Country/Region'].value_counts() #5

# %%
country_count
# Out:
# Country/Region
# Russia               249
# Brazil               162
# Colombia             146
# New                  142
# California           112
#                     ...
# Lombok                 1
# Marine                 1
# Minnesota46826/ 9      1
# NE                     1
# Zabul                  1
# Name: count, Length: 523, dtype: int64

# %%
top_country_count = country_count.head(10)

# %%
top_country_count
# Out:
# Country/Region
# Russia        249
# Brazil        162
# Colombia      146
# New           142
# California    112
# France        111
# Alaska        102
# India          96
# South          92
# Indonesia      88
# Name: count, dtype: int64

# %%
top_country_count.plot(kind='bar',figsize=(12,6),title='Number of crashes that occured in countries') 
plt.xlabel('countries that has the most plane crash')
plt.ylabel('Number of crashes')
plt.show()

# %%
plt.bar(df['Year'],df['Aboard']) #8
plt.xlabel('Year',fontsize=14)
plt.ylabel('Aboard',fontsize=14)
plt.title('People Aboard per year')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(df['Year'],df['Fatalities (air)']) #9
plt.xlabel('year',fontsize=14)
plt.ylabel('fatalities',fontsize=14)
plt.title('Dead per year')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['survivals_(air)'] = df['Aboard'] - df['Fatalities (air)'] #column for survival

# %%
df['survivals_(air)']
# Out:
# 0        3
# 1        0
# 2       37
# 3        0
# 4        0
#         ..
# 5030     0
# 5031     0
# 5032     0
# 5033     0
# 5034     0
# Name: survivals_(air), Length: 5035, dtype: int64

# %%
survivals_per_year = df.groupby('Year')['survivals_(air)'].sum()
survivals_per_year.head(100)
# Out:
# Year
# 1908      1
# 1909      0
# 1912      0
# 1913      6
# 1915     24
#        ...
# 2006    256
# 2007    577
# 2008    756
# 2009    534
# 2010    425
# Name: survivals_(air), Length: 100, dtype: int64

# %%
survivals_per_year_df = survivals_per_year.reset_index().rename(columns={'survivals_(air)':'Survivials in a year'})

# %%
survivals_per_year_df
# Out:
#      Year  Survivials in a year
# 0    1908                     1
# 1    1909                     0
# 2    1912                     0
# 3    1913                     6
# 4    1915                    24
# ..    ...                   ...
# 109  2020                   348
# 110  2021                    61
# 111  2022                   132
# 112  2023                     0
# 113  2024                   612
#
# [114 rows x 2 columns]

# %%
Negative_survivals = df[df['survivals_(air)']< 0]
Negative_survivals
# Out:
#       Year Quarter     Month  Day Country/Region Aircraft Manufacturer  \
# 48    1953   Qtr 2     April   10         Brazil               Doublas
# 172   1957   Qtr 2     April   20           Iraq        Lockheed Super
# 1234  1952   Qtr 4  December   22          Syria               Douglas
# 1513  1992   Qtr 1  February   20            NaN                Boeing
# 2013  1951   Qtr 1   January   20           Peru               Douglas
# 2290  1919   Qtr 3      July   21       Illinois               FD Type
# 2782  1956   Qtr 2      June   13            NaN               Douglas
# 2850  1957   Qtr 2      June   24     Queensland                     L
# 3411  1989   Qtr 2       May    9          China                  Bell
#
#                                 Aircraft  \
# 48                         Doublas Dc 3?
# 172   Lockheed Super ConstellationF BGNE
# 1234                       Douglas DC 3?
# 1513                       Boeing B 747?
# 2013                       Douglas DC 3?
# 2290                  FD Type Dirigible?
# 2782                       Douglas DC 3?
# 2850                          L  Hudson?
# 3411                      Bell 412JA9596
#
#                                                Location  \
# 48                          Near Anchieta Island Brazil
# 172                                        Jirkouk Iraq
# 1234                                     Damascus Syria
# 1513  En route from Argentina  to  CaliforniaAerolin...
# 2013                                        Huilyo Peru
# 2290                                   Chicago Illinois
# 2782                        Over North CarolinaPiedmont
# 2850                             Horn Island Queensland
# 3411                                 Near Tainjin China
#
#                                 Operator  Ground  Fatalities (air)  Aboard  \
# 48                                  REAL       0                26       0
# 172                           France Air       0                 1       0
# 1234                          Air Syrian       0                 9       0
# 1513                                 NaN       0                 1       0
# 2013                      TAM - Military       0                16       0
# 2290  Tire Goodyear Express Air Wingfoot      10                 3       0
# 2782                                 NaN       0                 1       0
# 2850           Australia Adastra Airways       0                 6       0
# 3411                          Asahi Aero       0                10       0
#
#      aircraft_manufacturer country/region     month day  survivals_(air)
# 48                 Doublas         Brazil     April  10              -26
# 172         Lockheed Super           Iraq     April  20               -1
# 1234               Douglas          Syria  December  22               -9
# 1513                Boeing            NaN  February  20               -1
# 2013               Douglas           Peru   January  20              -16
# 2290               FD Type       Illinois      July  21               -3
# 2782               Douglas            NaN      June  13               -1
# 2850                     L     Queensland      June  24               -6
# 3411                  Bell          China       May   9              -10

# %%
cleaned_Survivals = df[df["survivals_(air)"] >=0]

# %%
cleaned_Survivals
# Out:
#       Year Quarter      Month  Day Country/Region     Aircraft Manufacturer  \
# 0     1970   Qtr 2      April   28            NaN       de Havilland Canada
# 1     1952   Qtr 2      April   30            NaN                   Douglas
# 2     1973   Qtr 2      April   10            NaN          Vickers Vanguard
# 3     2000   Qtr 2      April   19        unknown                   Antonov
# 4     1946   Qtr 2      April   30        unknown                   Douglas
# ...    ...     ...        ...  ...            ...                       ...
# 5030  1980   Qtr 3  September   17          Zaire              De Havilland
# 5031  1997   Qtr 3  September   12          Zaire       de Havilland Canada
# 5032  1984   Qtr 3  September   11          Zaire  Handley Page Dart Herald
# 5033  1980   Qtr 3  September   14          Zaire         Lockheed Hercules
# 5034  1961   Qtr 3  September   17         Zambia                   Douglas
#
#                                         Aircraft                     Location  \
# 0     de Havilland Canada DHC 6 Twin Otter 100VH                      Kainatu
# 1                                 Douglas DC 3VT                        Delhi
# 2                     Vickers Vanguard 952G AXOP                   Near Basel
# 3                                 Antonov AN 8TL                      Pepa  -
# 4                            Douglas C 47A FZ559                Pindi-Khut  -
# ...                                          ...                          ...
# 5030                de Havilland DHC 5 Buffalo9T             Near Kindu Zaire
# 5031  de Havilland Canada DHC 6 Twin Otter 3009Q             Near Uvira Zaire
# 5032          Handley Page Dart Herald 2029Q CAH  Near the Kwango River Zaire
# 5033                   Lockheed Hercules C 1309T                  Kindu Zaire
# 5034                             Douglas DC 6BSE                 Ndola Zambia
#
#                                             Operator  Ground  \
# 0                 Airlines Australia GuineaTrans New       0
# 1                                Airways IndiaDeccan       0
# 2     (UK) Airlines International SwitzerlandInvicta       0
# 3                             Airlines Centrafricain       0
# 4                                    Force Air Royal       0
# ...                                              ...     ...
# 5030                    Force Air Zairean - Military       0
# 5031                                Commuter Air TMK       0
# 5032                               Services Aero MMM       0
# 5033              Zaïroise Aérienne Force - Military       0
# 5034                                 Sweden Transair       0
#
#       Fatalities (air)  Aboard     aircraft_manufacturer country/region  \
# 0                    8      11       de Havilland Canada            NaN
# 1                    9       9                   Douglas            NaN
# 2                  108     145          Vickers Vanguard            NaN
# 3                   24      24                   Antonov        unknown
# 4                   12      12                   Douglas        unknown
# ...                ...     ...                       ...            ...
# 5030                36      36              De Havilland          Zaire
# 5031                22      22       de Havilland Canada          Zaire
# 5032                30      30  Handley Page Dart Herald          Zaire
# 5033                36      36         Lockheed Hercules          Zaire
# 5034                16      16                   Douglas         Zambia
#
#           month day  survivals_(air)
# 0         April  28                3
# 1         April  30                0
# 2         April  10               37
# 3         April  19                0
# 4         April  30                0
# ...         ...  ..              ...
# 5030  September  17                0
# 5031  September  12                0
# 5032  September  11                0
# 5033  September  14                0
# 5034  September  17                0
#
# [5026 rows x 17 columns]

# %%
plt.bar(df['Year'],df['survivals_(air)']) #10
plt.xlabel('year',fontsize=14)
plt.ylabel('No of survivals_(air) ',fontsize=14)
plt.title('survivals_(air)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df
# Out:
#       Year Quarter      Month  Day Country/Region     Aircraft Manufacturer  \
# 0     1970   Qtr 2      April   28            NaN       de Havilland Canada
# 1     1952   Qtr 2      April   30            NaN                   Douglas
# 2     1973   Qtr 2      April   10            NaN          Vickers Vanguard
# 3     2000   Qtr 2      April   19        unknown                   Antonov
# 4     1946   Qtr 2      April   30        unknown                   Douglas
# ...    ...     ...        ...  ...            ...                       ...
# 5030  1980   Qtr 3  September   17          Zaire              De Havilland
# 5031  1997   Qtr 3  September   12          Zaire       de Havilland Canada
# 5032  1984   Qtr 3  September   11          Zaire  Handley Page Dart Herald
# 5033  1980   Qtr 3  September   14          Zaire         Lockheed Hercules
# 5034  1961   Qtr 3  September   17         Zambia                   Douglas
#
#                                         Aircraft                     Location  \
# 0     de Havilland Canada DHC 6 Twin Otter 100VH                      Kainatu
# 1                                 Douglas DC 3VT                        Delhi
# 2                     Vickers Vanguard 952G AXOP                   Near Basel
# 3                                 Antonov AN 8TL                      Pepa  -
# 4                            Douglas C 47A FZ559                Pindi-Khut  -
# ...                                          ...                          ...
# 5030                de Havilland DHC 5 Buffalo9T             Near Kindu Zaire
# 5031  de Havilland Canada DHC 6 Twin Otter 3009Q             Near Uvira Zaire
# 5032          Handley Page Dart Herald 2029Q CAH  Near the Kwango River Zaire
# 5033                   Lockheed Hercules C 1309T                  Kindu Zaire
# 5034                             Douglas DC 6BSE                 Ndola Zambia
#
#                                             Operator  Ground  \
# 0                 Airlines Australia GuineaTrans New       0
# 1                                Airways IndiaDeccan       0
# 2     (UK) Airlines International SwitzerlandInvicta       0
# 3                             Airlines Centrafricain       0
# 4                                    Force Air Royal       0
# ...                                              ...     ...
# 5030                    Force Air Zairean - Military       0
# 5031                                Commuter Air TMK       0
# 5032                               Services Aero MMM       0
# 5033              Zaïroise Aérienne Force - Military       0
# 5034                                 Sweden Transair       0
#
#       Fatalities (air)  Aboard     aircraft_manufacturer country/region  \
# 0                    8      11       de Havilland Canada            NaN
# 1                    9       9                   Douglas            NaN
# 2                  108     145          Vickers Vanguard            NaN
# 3                   24      24                   Antonov        unknown
# 4                   12      12                   Douglas        unknown
# ...                ...     ...                       ...            ...
# 5030                36      36              De Havilland          Zaire
# 5031                22      22       de Havilland Canada          Zaire
# 5032                30      30  Handley Page Dart Herald          Zaire
# 5033                36      36         Lockheed Hercules          Zaire
# 5034                16      16                   Douglas         Zambia
#
#           month day  survivals_(air)
# 0         April  28                3
# 1         April  30                0
# 2         April  10               37
# 3         April  19                0
# 4         April  30                0
# ...         ...  ..              ...
# 5030  September  17                0
# 5031  September  12                0
# 5032  September  11                0
# 5033  September  14                0
# 5034  September  17                0
#
# [5035 rows x 17 columns]

# %%
df
# Out:
#       Year Quarter      Month  Day Country/Region     Aircraft Manufacturer  \
# 0     1970   Qtr 2      April   28            NaN       de Havilland Canada
# 1     1952   Qtr 2      April   30            NaN                   Douglas
# 2     1973   Qtr 2      April   10            NaN          Vickers Vanguard
# 3     2000   Qtr 2      April   19        unknown                   Antonov
# 4     1946   Qtr 2      April   30        unknown                   Douglas
# ...    ...     ...        ...  ...            ...                       ...
# 5030  1980   Qtr 3  September   17          Zaire              De Havilland
# 5031  1997   Qtr 3  September   12          Zaire       de Havilland Canada
# 5032  1984   Qtr 3  September   11          Zaire  Handley Page Dart Herald
# 5033  1980   Qtr 3  September   14          Zaire         Lockheed Hercules
# 5034  1961   Qtr 3  September   17         Zambia                   Douglas
#
#                                         Aircraft                     Location  \
# 0     de Havilland Canada DHC 6 Twin Otter 100VH                      Kainatu
# 1                                 Douglas DC 3VT                        Delhi
# 2                     Vickers Vanguard 952G AXOP                   Near Basel
# 3                                 Antonov AN 8TL                      Pepa  -
# 4                            Douglas C 47A FZ559                Pindi-Khut  -
# ...                                          ...                          ...
# 5030                de Havilland DHC 5 Buffalo9T             Near Kindu Zaire
# 5031  de Havilland Canada DHC 6 Twin Otter 3009Q             Near Uvira Zaire
# 5032          Handley Page Dart Herald 2029Q CAH  Near the Kwango River Zaire
# 5033                   Lockheed Hercules C 1309T                  Kindu Zaire
# 5034                             Douglas DC 6BSE                 Ndola Zambia
#
#                                             Operator  Ground  \
# 0                 Airlines Australia GuineaTrans New       0
# 1                                Airways IndiaDeccan       0
# 2     (UK) Airlines International SwitzerlandInvicta       0
# 3                             Airlines Centrafricain       0
# 4                                    Force Air Royal       0
# ...                                              ...     ...
# 5030                    Force Air Zairean - Military       0
# 5031                                Commuter Air TMK       0
# 5032                               Services Aero MMM       0
# 5033              Zaïroise Aérienne Force - Military       0
# 5034                                 Sweden Transair       0
#
#       Fatalities (air)  Aboard     aircraft_manufacturer country/region  \
# 0                    8      11       de Havilland Canada            NaN
# 1                    9       9                   Douglas            NaN
# 2                  108     145          Vickers Vanguard            NaN
# 3                   24      24                   Antonov        unknown
# 4                   12      12                   Douglas        unknown
# ...                ...     ...                       ...            ...
# 5030                36      36              De Havilland          Zaire
# 5031                22      22       de Havilland Canada          Zaire
# 5032                30      30  Handley Page Dart Herald          Zaire
# 5033                36      36         Lockheed Hercules          Zaire
# 5034                16      16                   Douglas         Zambia
#
#           month day  survivals_(air)
# 0         April  28                3
# 1         April  30                0
# 2         April  10               37
# 3         April  19                0
# 4         April  30                0
# ...         ...  ..              ...
# 5030  September  17                0
# 5031  September  12                0
# 5032  September  11                0
# 5033  September  14                0
# 5034  September  17                0
#
# [5035 rows x 17 columns]
